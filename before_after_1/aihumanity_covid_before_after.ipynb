# %% [markdown]
# # 패키지 설치

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached bertopic-0.13.0-py2.py3-none-any.whl (103 kB)
# ...
#   Using cached PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
# ...
#   Using cached hdbscan-0.8.29.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 62.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.3 MB/s eta 0:00:00
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: bertopic 0.13.0 does not provide the extra 'visualization'
# ...

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 4.52 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 49.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 35.2 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-01-26 05:32:23--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %% [markdown]
# # 데이터 전처리

# %%
from bertopic import BERTopic
import pandas as pd

# %%
docs = pd.read_csv('/content/drive/MyDrive/jobplanet_df_stopword_preprocessed.csv')

# %%
docs.head()
# Out:
#      회사        날짜         직무 재직여부  별점  \
# 0  삼성전자  2023. 01      생산/제조  전직원   4
# 1  삼성전자  2023. 01  생산관리/품질관리  전직원   2
# 2  삼성전자  2023. 01         개발  현직원   4
# 3  삼성전자  2023. 01         개발  현직원   3
# 4  삼성전자  2023. 01      기획/경영  현직원   1
#
#                                                   요약  \
# 0                    힘들 지만 그만큼 급여 높 아 만족 였 던 곳 었 습니다
# 1             대 기업 라 부서 별 극 과 극 은 면 편하 고 구린 면 개고생 한다
# 2  국내 최대 의 회사 복지 급여 는 괜찮 은 편 지만 회사 버 는 돈 에 비해선 상당...
# 3                      임원직 마음 대로 인 회사 으로 는 처럼 은 회사 다
# 4            실제 주요 의사 결정권자 은 한국식 꼰대 판치 다 니 전혀 비전 는 곳
#
#                                                   장점  \
# 0                         힘든 만큼 급여 높 다 밥 정말 맛있 었 습니다
# 1                    PS 와 삼성 맨 라는 약간 의 자부심 대 기업 의 복지
# 2                 회사 다 니 그냥 묻 어 도 티 난다 월급 루팡 삼 무원 가능
# 3  복지 워 라벨 은 은 편 이나 이것 도 어느 사업 부 어느 사업장 에서 냐 에 따라...
# 4              테이크아웃 셔틀 인지 도 보너스 많이 나올 기준 적당 인성 의 동료
#
#                                                   단점  \
# ...

# %%
docs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37085 entries, 0 to 37084
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   회사           37085 non-null  object
#  1   날짜           37085 non-null  object
#  2   직무           37085 non-null  object
#  3   재직여부         37085 non-null  object
#  4   별점           37085 non-null  int64
#  5   요약           37085 non-null  object
#  6   장점           37074 non-null  object
#  7   단점           37023 non-null  object
#  8   경영진에게 바라는 점  37071 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.5+ MB

# %%
docs['날짜']=pd.to_datetime(docs['날짜'])

# %%
docs.head()
# Out:
#      회사         날짜         직무 재직여부  별점  \
# 0  삼성전자 2023-01-01      생산/제조  전직원   4
# 1  삼성전자 2023-01-01  생산관리/품질관리  전직원   2
# 2  삼성전자 2023-01-01         개발  현직원   4
# 3  삼성전자 2023-01-01         개발  현직원   3
# 4  삼성전자 2023-01-01      기획/경영  현직원   1
#
#                                                   요약  \
# 0                    힘들 지만 그만큼 급여 높 아 만족 였 던 곳 었 습니다
# 1             대 기업 라 부서 별 극 과 극 은 면 편하 고 구린 면 개고생 한다
# 2  국내 최대 의 회사 복지 급여 는 괜찮 은 편 지만 회사 버 는 돈 에 비해선 상당...
# 3                      임원직 마음 대로 인 회사 으로 는 처럼 은 회사 다
# 4            실제 주요 의사 결정권자 은 한국식 꼰대 판치 다 니 전혀 비전 는 곳
#
#                                                   장점  \
# 0                         힘든 만큼 급여 높 다 밥 정말 맛있 었 습니다
# 1                    PS 와 삼성 맨 라는 약간 의 자부심 대 기업 의 복지
# 2                 회사 다 니 그냥 묻 어 도 티 난다 월급 루팡 삼 무원 가능
# 3  복지 워 라벨 은 은 편 이나 이것 도 어느 사업 부 어느 사업장 에서 냐 에 따라...
# 4              테이크아웃 셔틀 인지 도 보너스 많이 나올 기준 적당 인성 의 동료
#
#                                                   단점  \
# ...

# %%
# 코로나 전 데이터
before = docs.query("날짜<'2020-01-01'")

# %%
# 코로나 후 데이터
after = docs.query("날짜>='2020-01-01'")

# %%
len(docs)
# Out:
# 37085

# %%
len(before)
# Out:
# 14371

# %%
len(after)
# Out:
# 22714

# %%
#before.to_csv('/content/drive/MyDrive/before.csv')

# %%
#after.to_csv('/content/drive/MyDrive/after.csv')

# %%
before = pd.read_csv('/content/drive/MyDrive/before.csv')

# %%
before.fillna('', inplace=True)

# %%
after = pd.read_csv('/content/drive/MyDrive/after.csv')

# %%
after.fillna('', inplace=True)

# %%
from sklearn.datasets import fetch_20newsgroups
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
docs
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
# ...

# %% [markdown]
# # 코로나 전 토픽 모델링(장점)

# %%
before['장점']
# Out:
# 0        수평 인 문화 로 눈치 고 할 는 곳 자율 출퇴근 제 로 엄청난 워 라벨 을 느낄 ...
# 1                 사업 기반 안정 고 보너스 음 새로운 기술 과 사업 분야 를 경험 할 음
# 2                                삼성 라는 자체 장점 지만 그만큼 단점 도 다
# 3                            연봉 주변 의 평가 복리 후생 근무 안정 성 우수 함
# 4        삼성전자 는 대한민국 에서 이미 대체 할 는 상징 성 마저 생겨버린 엄청난 회사 파...
#                                ...
# 14366           높 은 연봉 과 안정 인 복지 갖춰진 시스템 교육 의 기회 음 쉬 는 날 음
# 14367    노조 의 영향 으로 사 대리 쉬 는 날 고 고용 안정 성 보장 된다 국내 대 기업 ...
# 14368    연봉 복지 도 나름 어 는 법 차 땐 정말 음 연구소 는 현대 특유 의 딱딱 문화 ...
# 14369             글로벌 기업 의 자부심 을 느낄 었 음 구내식당 종류 별 로 나와 맛 음
# 14370                       매우 기회 고 승진 기회 도 습니다 돈 을 많이 줍니다
# Name: 장점, Length: 14371, dtype: object

# %%
df = before['장점'].to_list()

# %%
df
# Out:
# ['수평 인 문화 로 눈치 고 할 는 곳 자율 출퇴근 제 로 엄청난 워 라벨 을 느낄 는 곳 복지 역시 최고 의 수준 인 곳 재미있 는 이벤트 와 행사 아서 지루 은 곳',
#  '사업 기반 안정 고 보너스 음 새로운 기술 과 사업 분야 를 경험 할 음',
#  '삼성 라는 자체 장점 지만 그만큼 단점 도 다',
#  '연봉 주변 의 평가 복리 후생 근무 안정 성 우수 함',
#  '삼성전자 는 대한민국 에서 이미 대체 할 는 상징 성 마저 생겨버린 엄청난 회사 파격 인 대우 를 기대 긴 어려워 도 모든 부분 의 대우 에서 대한민국 평균 이상 의 수준 을 보장 해준다',
#  '안정 된 직장 고 직장 브랜드 와 평판 음 적정 급여 수준 과 복지',
#  '어느 기업 인지 설명 해도 모두 알아주 는 삼성전자 반도체 사업 부 에 대한 자부심 에 는 중소기업 연봉 수준 에 해당 는 성과 급부 바보 지만 자율 출퇴근 제 의 분 단위 이용 가능 여름 에 반바지 까지 허용 가능 근무 복장',
#  '부서 마다 다르 긴 한데 제 부서 는 연차 를 눈치 조금 긴 지만 자유 롭 게 쓸 도록 해 시 고 보너스 를 보다 많이 줘서 괜찮 습니다',
#  '자율 출퇴근 제 출퇴근 버스 의 우수 복지 시설 따로 설명 아도 아 는 기업',
#  '개발 제품 과 소프트웨어 를 수많 은 사용 여 보람 을 느낄 습니다 세끼 무료 로 제공 는 식사 맛있 습니다',
#  '교대 근무 긴 무엇 보다 돈 복지 습니다 도 습니다',
#  '다양 경험 을 쌓 릏 고 복지 혜택 우수 며 로열티 를 고 근무 할 음',
#  '장점 은 복리 후생 으로 분기 당 만 씩 복지 포인트 며 피복비 나온다',
#  '급여 음 밥 도 맛있 음 통근 버스 도 다양 해서 음',
#  '삼성 의 장점 은 당연히 복지 다 구내식당 과 식당 에서 먹 못해도 지원 해 준다 또한 아르바이트 생 에게 도 인센티브 를 준다 퇴근 도 준 해 며 외 의 에 퇴근 면 당연히 야근 수당 도 따로 챙겨준다',
# ...

# %%
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from bertopic import BERTopic

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 14371/14371 [00:00<00:00, 503704.83it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('연차', 0.07339000915296306), ('사용', 0.049736857193773375), ('눈치', 0.04395908754230897), ('자유', 0.03747439819529089), ('윗사람', 0.023492044057059586), ('가능', 0.021277271886350372), ('로운', 0.018891770463276517), ('로움', 0.017922963162870842), ('지만', 0.016525548017359767), ('분위기', 0.014990907610791268)]
# 1 번째 토픽 : [('맛있', 0.05107119600541357), ('식당', 0.04215804887900983), ('점심', 0.03592896874156047), ('식사', 0.03389537373415392), ('구내식당', 0.023908363447428495), ('사내', 0.02378595540962121), ('제공', 0.02266601213696144), ('아침', 0.021701925636275952), ('카페', 0.020909506074782782), ('습니다', 0.01875649781476179)]
# 2 번째 토픽 : [('삼성', 0.0704102286842144), ('서울', 0.05483545018836731), ('대한민국', 0.03531917645619303), ('한국', 0.03304977532670218), ('라는', 0.025602621599184232), ('에서', 0.023090471607704492), ('삼성전자', 0.018631689867428577), ('기업', 0.018455687951594406), ('자부심', 0.016492501768970293), ('최고', 0.015362529538146315)]
# ...

# %%
model.save('/content/drive/MyDrive/before_pros_model')

# %% [markdown]
# # 코로나 전 토픽 모델링(단점)

# %%
df = before['단점'].to_list()

# %%
df
# Out:
# ['개발 기간 짧 을 는 조금 바쁜 곳 최근 어 급변 는 인사 제도',
#  '불 필요 보고 및 회의 고 부서 간 의 협력 에 에너지 소비 음 수직 문화 잔존 고 음',
#  '여성 은 승진 어려움 상사 를 평가 할 어 상사 와 친한 에게 은 고과 를 줌 열심히 해서 성과 를 이룬다 해도 묵묵히 한다면 승진 의 빛 을 못함 퇴사 후 동종 업계 연간 재취업 불가 강제 으로 서명 해야 함 경력 단절 생김',
#  '근무 강도 강하 고 성과 지향 경쟁 에 스트레스 심한 편 며 회사 커서 관료주의 는 편',
#  '부서 별 문화 워낙 다양 해서 한마디 로 기업 의 단점 을 정의 기 는 어렵 지만 회서 규모 다 니 시대 흐름 에 맞춘 적절 변화 항상 느림 일부 부서 보여 기 식 도입 은 대한민국 에서 가장 빠름 과거 올드 패션 마인드 로 의 자리 까지 올라가 신 경영진 의 옛날 제조업 사고방식 은 어쩔 다',
#  '상하 관계 강한 직장 문화 사업 부 간 부서 간 연봉 근무 의 불 평등 존재',
#  '조직 별 로 전혀 공정 은 성과 구조 임 을 고 는 게 게 반영 고 어느 부서 에 어느 타이밍 에 었 는지 에 따라 재수 으면 상위 고과 에 발탁 도 가능 비 메인 부서 시스템 인프라 환경 에서 진급 려고 노력 는 조직자 을 위한 과도 문서 작업',
#  '제 그렇게 많이 다니 는 아서 아직 은 는 게 지만 단점 을 자면 안에 엄격 습니다 사내 에서 는 어 플로 카메라 도 게 니깐 요 그래도 그렇게 큰 단점 은 아닙니다',
#  '내부 경쟁 정치 심함 부서 직무 에 따라 전문 지식 습득 차이 음 회사 사업 부 부서 별 차이 너무 심함 불 합리 시스템 음',
#  '도덕 못한 발생 고 으로 지탄 을 고 는대서 자괴감 느껴집니다',
#  '교대 근무 라서 생활 패턴 일정 아 맞 는 에게 는 힘들 습니다',
#  '업무 의 강도 높 은 편 며 책임 감 도 무겁 게 어 기 에 스트레스 높 음 그럴지라도 지나 면 업무 전문가 될 기 에 는 음',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 14371/14371 [00:00<00:00, 150585.07it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('너무', 0.021215014415895996), ('단점', 0.016954131316806297), ('분위기', 0.015096596263567396), ('부서', 0.01404949749759147), ('힘들', 0.01328643872156635), ('지만', 0.012494506894585037), ('조금', 0.012206698781701168), ('야근', 0.012161251858241271), ('업무', 0.011622940220654472), ('많이', 0.01141825200682084)]
# 1 번째 토픽 : [('회사', 0.020957000197376903), ('사업', 0.017516824935172266), ('기업', 0.014128971739210724), ('으로', 0.014098603440173989), ('직원', 0.013727249249537355), ('임원', 0.01294471782714228), ('부서', 0.012815660867356752), ('에서', 0.012338438803765723), ('업무', 0.011345596440452497), ('조직', 0.01080262044752362)]
# 2 번째 토픽 : [('군대', 0.1256140088107091), ('문화', 0.08306721264987776), ('군대식', 0.06824239505108723), ('아직', 0.028722566029603727), ('수직', 0.016047000123276485), ('많이', 0.01581292186658837), ('존재', 0.01556473597988583), ('꼰대', 0.015169737978568586), ('지만', 0.014318904599626104), ('부서', 0.014129403947120466)]
# ...

# %%
model.save('/content/drive/MyDrive/before_cons_model')
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/sparse/_index.py:125: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %% [markdown]
# # 코로나 후 토픽모델링(장점)

# %%
df = after['장점'].to_list()

# %%
df
# Out:
# ['힘든 만큼 급여 높 다 밥 정말 맛있 었 습니다',
#  'PS 와 삼성 맨 라는 약간 의 자부심 대 기업 의 복지',
#  '회사 다 니 그냥 묻 어 도 티 난다 월급 루팡 삼 무원 가능',
#  '복지 워 라벨 은 은 편 이나 이것 도 어느 사업 부 어느 사업장 에서 냐 에 따라 차이 심하 다',
#  '테이크아웃 셔틀 인지 도 보너스 많이 나올 기준 적당 인성 의 동료',
#  '연차 를 눈치 고 쓸 고 급여 수준 괜찮 고 조직 문화 나쁘 음',
#  '일단 주변인 에게 삼성 에 근무 한다는 으로 도 신원 확실히 보장 는 느낌 누릴 는 복지 았 고 상식 고 합리 인 직원 로 구성 됨 으로써 에서 는 시너지 았 다',
#  '연봉 과 자잘 복지 고 에게 굳이 설명 필요 다',
#  '하루 아침 점심 저녁 무료 제공 경기 남부 및 서울 전역 셔틀버스 수평 인 분위기 세계 인 기술력 과 체계 인 시스템',
#  '사내 분위기 에 따라 업무 량 다름 밥 을 굳이 사 먹 으러 나갈 필요 음 프리랜서 라도 대우 나쁘 음',
#  '자유 로운 연차 높 은 급여 복지 미래 는 기업',
#  '주변 의 평판 은 괜찮 음 부모 님 아 하심 기본 인 으로서 의 복지 는 지켜 줌 성과급 나올 는 연봉 도 괜찮 은 편',
#  '연차 사용 자율 자율 출퇴근 부부 부 지만 대체로 노터치 눈치 는 보일 음 개인 발전 을 위한 교육 측면 지원 늘어나 는 게 체감 됨 식사 및 출퇴근 교통 복지 어 음',
#  '의료비 지원 각종 리조트 수당 풍부 복리 후생 혜택 다',
#  '능력 출중 동료 체계 갖춰 짐 선진 시스템 식당 다 메뉴 아서 먹 고 은 거 골라 먹 음',
#  '시스템 은 어 습니다 근무지 수도 권 라는 도 장점 식사 맛있 습니다',
#  '아무래도 네임 밸류 큰 습니다 파랑 목걸이 를 느낌',
#  '대 기업 으로서 기본 복지 대우 다 삼성 글자 로 뭐 는지 해도 됨',
#  '글로벌 대 기업 인 만큼 전 세계 의 산업 한국 본사 에서 시작 한다는 자부심',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 22714/22714 [00:00<00:00, 449161.60it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('연차', 0.06865941635062804), ('사용', 0.04960597997076515), ('눈치', 0.04295172524202472), ('자유', 0.0396084170194552), ('가능', 0.023421578006933567), ('윗사람', 0.02088237597847685), ('로운', 0.019553189837961983), ('로움', 0.01697424140975914), ('분위기', 0.014310901900082496), ('습니다', 0.013679984049509125)]
# 1 번째 토픽 : [('맛있', 0.05123499919283449), ('식당', 0.039422078286220394), ('식사', 0.0352191423934316), ('점심', 0.034634223654691966), ('구내식당', 0.02503006476969698), ('제공', 0.022834014373233787), ('사내', 0.022642408301914132), ('아침', 0.02172001005943174), ('저녁', 0.02150278697953779), ('메뉴', 0.01886883289311854)]
# 2 번째 토픽 : [('버스', 0.15266736903287484), ('통근', 0.092246523470434), ('출퇴근', 0.05780493482614004), ('셔틀버스', 0.041238463286873146), ('식사', 0.02709560942409103), ('운행', 0.02421877876227871), ('제공', 0.021891136025583607), ('운영', 0.019771083223203374), ('맛있', 0.01802799437401003), ('어서', 0.01661705049585136)]
# ...

# %%
model.save('/content/drive/MyDrive/after_pros_model')

# %% [markdown]
# # 코로나 후 토픽 모델링(단점)

# %%
df = after['단점'].to_list()

# %%
df
# Out:
# ['로 인해 많이 피곤 였 다 연고지 랑 너무 멀 었 습니다',
#  '반도체 F 직군 은 그냥 헬 다 대체 초 가능 인력 으로 업무 방식 도 주먹구구 이슈 터지 면 자 부서 책임 회피 에 온 힘 을 쏟 는 느낌 의 보람 은 다고 면 된다 그냥 회용 부속품 으로 뇌 빼 고 면서 서 줄 까지 대 기업 연봉 고 은 분 은 추천',
#  '연봉 피에스 에 영향 을 많이 음 열심히 는 도 인정 을 못 을 도 다',
#  '비 효율 지시 부당 지시 사업 부 마다 차별 심하 다 사업 부 를 본인 선택 으로 간 도 지만',
#  '업무 방식 주먹구구 투 올드햄 승진 체계 리더 급 에 꼰대 고 그게 당연 분위기',
#  '딱히 찾 을 순 지만 워라 밸 깨지 는 부마부 구조 인 다 외 에 는 딱히 음',
#  '조금 은 경직 된 조직 문화 효율 을 강조 지만 보다 는 효율 못한 시스템 아쉬웠 지만 큰 기업 시스템 에서 는 어쩔 는 부분 라고 됨',
#  '경영진 과 의 의사소통 부재 로 답답 할 다 그래서 이것 을 단점 으로 꼽 습니다',
#  '과제 프로젝트 에 따른 업무 load 으면 는 만큼 해야 는 책임감',
#  '은 게 단점 이유 는 은 도 은 밥 먹 을 으니 줄 서 는 게 귀찮 음',
#  '지방 라 출퇴근 의 걸림돌 이외 엔 단점 다',
#  '지나친 경쟁 의 강요 로 인한 피로감 단기 성과 로 인한 보여 기 식 경쟁이 로 인한 직원 의 피로 도 과부하 와 기계 인 대응 으로 일관 는 문화 이슈 발생 시 책임 떠넘기 기 일반 화 미래 성장 동력 에 대한 의문 음',
#  '수직 인 문화 기업 고 다 니 고쳐 기 쉽 으면 돌아가 는 생산 라인 특성 상 주말 공휴일 없이 교대 근무 에 해당 는 직군 음 하이닉스 대비 압도 인 영업 이익 에 도 떨어지 는 조직 문화 복지',
#  '서류 작업 복잡 고 작업 에 대한 준비 과정 까다롭 다 환경 안전 의 경영 방침 으로 위험 면 바로 작업 중지',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 22714/22714 [00:00<00:00, 528382.18it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('너무', 0.02330174195361563), ('힘들', 0.014396757311237705), ('아요', 0.014146735445269124), ('아서', 0.014105317097427255), ('네요', 0.014072441088883789), ('부서', 0.013855137988114174), ('그냥', 0.013046493804041194), ('업무', 0.01302932819600044), ('근무', 0.012586319297041265), ('조금', 0.01240284832251218)]
# 1 번째 토픽 : [('연봉', 0.06625748784875822), ('대비', 0.049285458683996294), ('급여', 0.03440560679315561), ('비해', 0.033499066005810506), ('업계', 0.03045518127768116), ('기업', 0.028231467571774582), ('복지', 0.02611688841039336), ('동종', 0.025954209554334192), ('상승', 0.025525808000777625), ('수준', 0.024287378657522885)]
# 2 번째 토픽 : [('보고', 0.12424381048973601), ('문서', 0.12085077993737699), ('위한', 0.10596862805702674), ('작업', 0.09442247642749871), ('작성', 0.07494288749661293), ('단순', 0.06795131569917426), ('보고서', 0.04956856775112489), ('효율', 0.044343943630534566), ('자료', 0.03472157307395351), ('서류', 0.03169486668556574)]
# ...

# %%
model.save('/content/drive/MyDrive/after_cons_model')
