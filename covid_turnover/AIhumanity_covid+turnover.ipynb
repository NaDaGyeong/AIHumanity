# %% [markdown]
# # 데이터 전처리

# %%
import pandas as pd

# %%
# 코로나 전
before = pd.read_csv('/content/drive/MyDrive/before.csv')
before.fillna('', inplace=True)

# %%
# 코로나 후
after = pd.read_csv('/content/drive/MyDrive/after.csv')
after.fillna('', inplace=True)

# %%
# 코로나 전 + 전직원
before_former = before.query("재직여부=='전직원'")
before_former.head()
# Out:
#     Unnamed: 0    회사          날짜         직무 재직여부  별점  \
# 2         3612  삼성전자  2019-12-01  생산관리/품질관리  전직원   1
# 5         3615  삼성전자  2019-12-01      기획/경영  전직원   3
# 6         3616  삼성전자  2019-12-01         개발  전직원   4
# 9         3619  삼성전자  2019-12-01       연구개발  전직원   4
# 10        3620  삼성전자  2019-12-01      엔지니어링  전직원   4
#
#                                                    요약  \
# 2                    빛 은 개살구 내부 의 상황 은 매우 다 형광 을 뺀다거나
# 5            국내 에서 알아주 는 기업 고 안정 된 직장 이나 기업 문화 는 후진 임
# 6   세계 최대 의 반도체 회사 의 역량 과 치열 내부 경쟁 에 따른 높 은 성과 를 경...
# 9              글로벌 개발자 과 협업 며 개인 의 커리어 를 성장 시켜 나갈 습니다
# 10                   역시 삼성 다 대 기업 다운 연봉 복지 은 경험 었 습니다
#
#                                                    장점  \
# 2                           삼성 라는 자체 장점 지만 그만큼 단점 도 다
# 5               안정 된 직장 고 직장 브랜드 와 평판 음 적정 급여 수준 과 복지
# 6   어느 기업 인지 설명 해도 모두 알아주 는 삼성전자 반도체 사업 부 에 대한 자부심...
# 9   개발 제품 과 소프트웨어 를 수많 은 사용 여 보람 을 느낄 습니다 세끼 무료 로 ...
# ...

# %%
# 코로나 전 + 현직원
before_incumbent = before.query("재직여부=='현직원'")
before_incumbent.head()
# Out:
#    Unnamed: 0    회사          날짜     직무 재직여부  별점  \
# 0        3610  삼성전자  2019-12-01   연구개발  현직원   5
# 1        3611  삼성전자  2019-12-01     개발  현직원   4
# 3        3613  삼성전자  2019-12-01  인사/총무  현직원   4
# 4        3614  삼성전자  2019-12-01  기획/경영  현직원   3
# 7        3617  삼성전자  2019-12-01  생산/제조  현직원   4
#
#                                                   요약  \
# 0                           나라 최고 의 기업 인 이유 를 느낄 는 곳
# 1                                    개발자 대우 으며 할 는 곳
# 3                     글로벌 회사 시스템 선도 기업 다양 학습 과 경험 가능
# 4  대한민국 제 기업 답 게 뛰어난 경영 성과 창출 과 선진 기업 문화 도입 및 제도 ...
# 7               대 기업 답 게 확실히 문화 도 고 돈 도 많이 줘서 괜찮 습니다
#
#                                                   장점  \
# 0  수평 인 문화 로 눈치 고 할 는 곳 자율 출퇴근 제 로 엄청난 워 라벨 을 느낄 ...
# 1           사업 기반 안정 고 보너스 음 새로운 기술 과 사업 분야 를 경험 할 음
# 3                      연봉 주변 의 평가 복리 후생 근무 안정 성 우수 함
# 4  삼성전자 는 대한민국 에서 이미 대체 할 는 상징 성 마저 생겨버린 엄청난 회사 파...
# 7  부서 마다 다르 긴 한데 제 부서 는 연차 를 눈치 조금 긴 지만 자유 롭 게 쓸 ...
#
# ...

# %%
# 코로나 후 + 전직원
after_former = after.query("재직여부=='전직원'")
after_former.head()
# Out:
#     Unnamed: 0    회사          날짜         직무 재직여부  별점  \
# 0            0  삼성전자  2023-01-01      생산/제조  전직원   4
# 1            1  삼성전자  2023-01-01  생산관리/품질관리  전직원   2
# 5            5  삼성전자  2023-01-01      기획/경영  전직원   5
# 9            9  삼성전자  2023-01-01         개발  전직원   4
# 10          10  삼성전자  2023-01-01      생산/제조  전직원   5
#
#                                         요약  \
# 0          힘들 지만 그만큼 급여 높 아 만족 였 던 곳 었 습니다
# 1   대 기업 라 부서 별 극 과 극 은 면 편하 고 구린 면 개고생 한다
# 5       커리어 를 쌓 기 고 급여 수중 높 다 대체 으로 만족 스러움
# 9                개발자 기 에 은 회사 은 는 만큼 은 은 다
# 10                 든 기업 답 게 은 급여 를 제공 는 기업
#
#                                                    장점  \
# 0                          힘든 만큼 급여 높 다 밥 정말 맛있 었 습니다
# 1                     PS 와 삼성 맨 라는 약간 의 자부심 대 기업 의 복지
# 5                 연차 를 눈치 고 쓸 고 급여 수준 괜찮 고 조직 문화 나쁘 음
# 9   사내 분위기 에 따라 업무 량 다름 밥 을 굳이 사 먹 으러 나갈 필요 음 프리랜서...
# 10                         자유 로운 연차 높 은 급여 복지 미래 는 기업
#
# ...

# %%
# 코로나 후 + 현직원
after_incumbent = after.query("재직여부=='현직원'")
after_incumbent.head()
# Out:
#    Unnamed: 0    회사          날짜         직무 재직여부  별점  \
# 2           2  삼성전자  2023-01-01         개발  현직원   4
# 3           3  삼성전자  2023-01-01         개발  현직원   3
# 4           4  삼성전자  2023-01-01      기획/경영  현직원   1
# 6           6  삼성전자  2023-01-01         개발  현직원   4
# 7           7  삼성전자  2023-01-01  생산관리/품질관리  현직원   4
#
#                                                   요약  \
# 2  국내 최대 의 회사 복지 급여 는 괜찮 은 편 지만 회사 버 는 돈 에 비해선 상당...
# 3                      임원직 마음 대로 인 회사 으로 는 처럼 은 회사 다
# 4            실제 주요 의사 결정권자 은 한국식 꼰대 판치 다 니 전혀 비전 는 곳
# 6  대한민국 최고 의 기업 에서 한다는 자체 았 습니다 전반 인 직원 능력 매우 뛰 어...
# 7                   개발자 다양 게 의견 을 존중 는 곳 므로 추천 할 만 함
#
#                                                   장점  \
# 2                 회사 다 니 그냥 묻 어 도 티 난다 월급 루팡 삼 무원 가능
# 3  복지 워 라벨 은 은 편 이나 이것 도 어느 사업 부 어느 사업장 에서 냐 에 따라...
# 4              테이크아웃 셔틀 인지 도 보너스 많이 나올 기준 적당 인성 의 동료
# 6  일단 주변인 에게 삼성 에 근무 한다는 으로 도 신원 확실히 보장 는 느낌 누릴 는...
# 7                         연봉 과 자잘 복지 고 에게 굳이 설명 필요 다
#
# ...

# %%
#before_former.to_csv('/content/drive/MyDrive/before_former.csv')
#before_incumbent.to_csv('/content/drive/MyDrive/before_incumbent.csv')
#after_former.to_csv('/content/drive/MyDrive/after_former.csv')
#after_incumbent.to_csv('/content/drive/MyDrive/after_incumbent.csv')

# %% [markdown]
# # 패키지 설치

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.9/103.9 KB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 38.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 80.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 23.9 MB/s eta 0:00:00
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: bertopic 0.13.0 does not provide the extra 'visualization'
# ...

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 9.16 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 40.8 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-01-27 01:21:41--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %%
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from bertopic import BERTopic

# %% [markdown]
# # 코로나 전 전직 토픽 모델링

# %%
before_former['요약']
# Out:
# 2                         빛 은 개살구 내부 의 상황 은 매우 다 형광 을 뺀다거나
# 5                 국내 에서 알아주 는 기업 고 안정 된 직장 이나 기업 문화 는 후진 임
# 6        세계 최대 의 반도체 회사 의 역량 과 치열 내부 경쟁 에 따른 높 은 성과 를 경...
# 9                   글로벌 개발자 과 협업 며 개인 의 커리어 를 성장 시켜 나갈 습니다
# 10                        역시 삼성 다 대 기업 다운 연봉 복지 은 경험 었 습니다
#                                ...
# 14360           탄탄 수익 구조 를 지녀 안정 성 뛰어나 지만 기술력 면 에선 미래 확실 다
# 14363       나라 최고 의 부품 업계 지고 복지 및 연봉 높 지만 급성장 탓 에 시스템 미비 함
# 14364                 네임 밸류 굿 팀 배치 에 따라 근무 비교 불가 연봉 상승 률 음
# 14365     현대차 계열 네임 밸류 그게 다인 회사 사원 대리 까지 는 은 회사 이상 이하 도 아님
# 14369      글로벌 제조사 에서 의 새로운 경험 을 할 다 회사 엌덯 게 돌아가 는지 배울 었 다
# Name: 요약, Length: 8549, dtype: object

# %%
df = before_former['요약'].to_list()

# %%
df
# Out:
# ['빛 은 개살구 내부 의 상황 은 매우 다 형광 을 뺀다거나',
#  '국내 에서 알아주 는 기업 고 안정 된 직장 이나 기업 문화 는 후진 임',
#  '세계 최대 의 반도체 회사 의 역량 과 치열 내부 경쟁 에 따른 높 은 성과 를 경험 해 볼 다',
#  '글로벌 개발자 과 협업 며 개인 의 커리어 를 성장 시켜 나갈 습니다',
#  '역시 삼성 다 대 기업 다운 연봉 복지 은 경험 었 습니다',
#  '복리 후생 은 으나 수직 인 기업 구조 였 음',
#  '공장 효율 으로 돌아가 게 설계 됨 근무자 입장 에선 쉬 는 별로 단 지만 그만큼 돈 은 챙겨 줌',
#  '역시 삼성 다 복지 외 의 모든 편안 했 다 엄무 형태 도 보다 빡세 진 았 다',
#  '조직 문화 유연 고 업무 량 도 지만 최고 기업 의 업무 프로세스 를 익힐 고 높 은 연봉 과 복지 다',
#  '글로벌 제조사 로서 학력 낮 음 에 도 전 에 경험 해 못한 급여 를 을 었 습니다',
#  '파 견기 에서 최상 의 급여 복지 사내 문화 를 보유 기업 급여 면 에서 여타 파 견직 비교 됨',
#  '개발자 대우 으면 보람차 게 했 습니다 행복 합니다',
#  '누구 고 어 는 기업 라 자부심 을 느낄 다',
#  '어릴 부터 꿈꿔왔 던 기업 기 에 항상 은 경험 으로 합니다 보다 은 미래 에 발판 될 었 던 기회 인 거 습니다',
#  'IT 회사 고 어 는 오너 와 를 맞추 기 위한 제조 회사 꼰대 의 좌충우돌 밑 에서 충성 스러운 중간 매니저 의 신파극',
#  '이러나저러나 직장인 으로서 다니 기 은 회사 임 은 분명 함',
#  '대 기업 에서 할 는 기회 여러 부서 와 협업 해서 을 지만 혼자 서 디자인 업무 를 해야 함',
#  '역시 삼성 만 곳 다 모든 부문 에서 선도 인 역할 을 한다',
#  '특화 된 에 집중 는 기업 며 개인 인 성향 강하 다',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 8549/8549 [00:00<00:00, 296479.37it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('게임', 0.45573587580761926), ('업계', 0.07340428978998996), ('회사', 0.06816062136256319), ('복지', 0.04053277809152463), ('최고', 0.03446968821849591), ('넥슨', 0.033818255438774245), ('좋아하', 0.03240476353122758), ('에서', 0.031242433090255674), ('개발', 0.029581695181670007), ('퍼블리싱', 0.02922055562740265)]
# 1 번째 토픽 : [('자동차', 0.3179045213629647), ('현대', 0.09949083368350418), ('생산', 0.040606477303534665), ('나라', 0.03760606527656241), ('최고', 0.037464595555512764), ('국내', 0.03710916781400154), ('기업', 0.032117878758861435), ('으로', 0.029641389804767364), ('회사', 0.027798414150265675), ('제조', 0.026775517882288172)]
# 2 번째 토픽 : [('항공사', 0.39259536526954464), ('항공', 0.20357316248480245), ('대한항공', 0.135187024735224), ('나라', 0.09010684053173056), ('비행', 0.06341482285095895), ('승무원', 0.062466852764412134), ('항공업', 0.05752063877419561), ('역시', 0.05541896841255389), ('자부심', 0.047506872610500524), ('로서', 0.04698765990888825)]
# ...

# %%
model.save('/content/drive/MyDrive/before_former_model')

# %% [markdown]
# # 코로나 전 현직 토픽 모델링

# %%
df = before_incumbent['요약'].to_list()
df
# Out:
# ['나라 최고 의 기업 인 이유 를 느낄 는 곳',
#  '개발자 대우 으며 할 는 곳',
#  '글로벌 회사 시스템 선도 기업 다양 학습 과 경험 가능',
#  '대한민국 제 기업 답 게 뛰어난 경영 성과 창출 과 선진 기업 문화 도입 및 제도 혁신 시도 활발 게 이루어지 는 최고 의 회사 지만 그만큼 은 직장 냐는 질문 에 는 선뜻 맞 는다고 대답 기 어려움',
#  '대 기업 답 게 확실히 문화 도 고 돈 도 많이 줘서 괜찮 습니다',
#  '남 다 아 는 기업 보다 주변 만족 함 사업 부 에 따른 편차 심하 고 내부 경쟁 과 소모품 취급 당함',
#  '다양 경험 을 쌓 을 고 복지 혜택 우수 며 로열티 를 고 근무 할 음',
#  '음 삼성전자 라면 곳 에 취직 한다는 만 으로 주변 평판 음',
#  '임직원 에 대한 배려 부족 기업 그대로 부품',
#  '무난 직장 에 따라 지루 할 도 편안 할 도 는',
#  '세계 반도체 위 를 다투 는 회사 산업 에 비해 경기 흐름 을 타 는 듯 함',
#  '연봉 에 만족 며 지낼 으나 거대 시스템 주어진 역할 한정 임',
#  '고 는 보다 는 괜찮 은 곳 나름 나라 에서 선진 기업 문화 를 갖 고 고 직원 복지 에 신경 을 많이 쓰 는 회사',
#  '상위 권 연봉 과 뛰어난 복지 관리 의 삼성 라는 에 걸맞 게 교육 기회 도 고 직원 개개인 의 특성 을 어느 고려 해 줌',
#  '메모리 제조 센터 기술 팀 설비 엔지니어 로서 스마트 시스템 으로 단순 막노동 반복 는 업무',
#  '글로벌 기업 답 게 다양 프로젝트 와 시장 변화 를 경험 할 음 반면 통제 고 폐쇄 인 개발 환경 으로 인해 보수 인 면 다분 함',
#  '회사 워낙 넓 어서 부서 마다 천차만별 본인 던 부서 는 동기 에 비해 편한 부서 였으나 동기 은 힘든 부서 도 들어감 하지만 상대 으로 편한 뿐 는 만큼 시킨다 돈 은 확실히 많이 줌',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 5822/5822 [00:00<00:00, 106510.51it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('라벨', 0.02115291254799164), ('부서', 0.020882813562677776), ('분위기', 0.017725458935596416), ('너무', 0.015934206950416963), ('아요', 0.01577701795590672), ('습니다', 0.013883585737841634), ('다니', 0.013729085108504601), ('괜찮', 0.013459315927850074), ('다닐', 0.013335697189557242), ('워라', 0.012913870495171259)]
# 1 번째 토픽 : [('개발자', 0.15837927415643605), ('대우', 0.0644805285778083), ('개발', 0.0599071561140061), ('로서', 0.032844477207329234), ('으며', 0.029379430071010106), ('에게', 0.02247089453674517), ('소프트웨어', 0.02241021989536636), ('으면서', 0.020060568029463148), ('보람차', 0.017733859603903956), ('실력', 0.015987699291556183)]
# 2 번째 토픽 : [('연봉', 0.04561587846522058), ('급여', 0.03315894060725354), ('비해', 0.032546468509901776), ('대비', 0.029476437475573214), ('임금', 0.027366834838063632), ('지만', 0.0256606812674497), ('동종', 0.023967364890321245), ('복지', 0.02253621312611424), ('워라', 0.021145346223672826), ('근무', 0.018640764983818663)]
# ...

# %%
model.save('/content/drive/MyDrive/before_incumbent_model')

# %% [markdown]
# # 코로나 후 전직 토픽 모델링

# %%
df = after_former['요약'].to_list()
df
# Out:
# ['힘들 지만 그만큼 급여 높 아 만족 였 던 곳 었 습니다',
#  '대 기업 라 부서 별 극 과 극 은 면 편하 고 구린 면 개고생 한다',
#  '커리어 를 쌓 기 고 급여 수중 높 다 대체 으로 만족 스러움',
#  '개발자 기 에 은 회사 은 는 만큼 은 은 다',
#  '든 기업 답 게 은 급여 를 제공 는 기업',
#  '엔지니어 로서 업무 와 안전 에 대해 국내 위 답 게 체계 인 교육 을 을 다',
#  '대한민국 최고 의 직장 대 기업 의 표준 누구 고 어 는 기업',
#  '역시 대 기업 답 게 복지 및 급여 는 만족 합니다 이상 이하 도 아닌',
#  '팀원 조직원 개개인 은 너무 지만 보여 기 식 업무 문화 강하 고 임원 인 신인',
#  '삼성전자 생활 가전 은 일대 로 지만 내주 에서 대우 못함',
#  '국내 최고 기업 에 는 이유 다 에 맞 는 업무 와 보상 맞 는 과 아닌 명확 편',
#  '처음 경력 쌓 기 은 곳 국내 에서 기 제일 은 기업',
#  '쳬격적인 업무 와 환경 면서 배울 는 부분 다',
#  '미래 를 투자 할 는 회사 라는 로 꼭 한번 다녀볼 만 회사 입니다',
#  '높 은 보수 강 도 높 은 근무 풍족 복지',
#  '은 과 은 회사 에서 함 시스템 갖춰져 고 급여 만 졷',
#  '삼성 라는 회사 의 네임 드 음 누구 한테 면 삼 성 다녀 고 부러워 함',
#  '높 은 연봉 과 워라 밸 다양 경험 의 커리어',
#  '적당히 챙겨 고 많이 도록 는 구조 인 습니다',
#  '밥 고 복지 너무 은 회사 입니다',
#  '자부심 느끼 며 할 고 향후 커리어 를 도모 할 는 곳',
#  '삼성전자 란 대한민국 을 넘 어서 전 세계 으로 유명 기업 에서 할 다는 성취감',
#  '삼성 은 삼성 다 별 탈 없이 살아가 는데 지장 다',
#  '돈 만 면 은 곳 이나 근무 분위기 너무 힘들 었 던 곳',
#  '는 강도 에 비해 급여 습니다',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 12695/12695 [00:00<00:00, 433255.68it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('개발자', 0.18593852857974505), ('개발', 0.07922525746276532), ('대우', 0.06589203966319543), ('으며', 0.051856101211301645), ('으면서', 0.032942955442239824), ('보람차', 0.030214849652278917), ('로서', 0.025810002465821765), ('에게', 0.020650097240475628), ('환경', 0.018947089176347062), ('입니다', 0.01760453515822684)]
# 1 번째 토픽 : [('나쁘', 0.043979776194697805), ('지만', 0.034531203334099016), ('다르', 0.028272395480895312), ('분위기', 0.02092826157766492), ('마다', 0.0191349248601455), ('장점', 0.018554936177752716), ('혼자', 0.017830030731689782), ('부서', 0.01730644327646183), ('습니다', 0.017285028220341635), ('꼰대', 0.017006003709342875)]
# 2 번째 토픽 : [('안정', 0.052455397899287735), ('만족', 0.045619088974070715), ('회사', 0.03415238579356305), ('자부심', 0.03263313283265527), ('기업', 0.03152420066494275), ('복지', 0.02675328335733079), ('자유', 0.02419459791576232), ('느낄', 0.02395984807970057), ('습니다', 0.022286978864635185), ('존중', 0.02144559056383712)]
# ...

# %%
model.save('/content/drive/MyDrive/after_former_model')

# %% [markdown]
# # 코로나 후 현직 토픽 모델링

# %%
df = after_incumbent['요약'].to_list()
df
# Out:
# ['국내 최대 의 회사 복지 급여 는 괜찮 은 편 지만 회사 버 는 돈 에 비해선 상당히 인색 함',
#  '임원직 마음 대로 인 회사 으로 는 처럼 은 회사 다',
#  '실제 주요 의사 결정권자 은 한국식 꼰대 판치 다 니 전혀 비전 는 곳',
#  '대한민국 최고 의 기업 에서 한다는 자체 았 습니다 전반 인 직원 능력 매우 뛰 어 납니다',
#  '개발자 다양 게 의견 을 존중 는 곳 므로 추천 할 만 함',
#  '연봉 과 복지 매우 은 회사 국내 탑 대 기업 자 글로벌 회사 에 다닌다는 자부심 을 가질 음',
#  '지나치 게 과 경쟁 의 로 인한 피로감',
#  '규모 의 경제 훌륭 다 업무 및 외 으로 배울 은 회사',
#  '예전 네임 밸류 로 먹 고 사 는 현재 는 점점 퇴보 는 회사',
#  '세계 최고 의 회사 라는 자부심 자부심 오래가 는다',
#  '본인 보다 부모 님 자랑 스러워 시 는 직장',
#  '에 집중 기 에 는 최고 의 환경 요즘 은 워 라벨 도 으나 부서 별 케 바케',
#  '아침 점심 저녁 야식 까지 무료 로 다 나옴 통근 버스 어 고 미래 에 대해 항상 나아가 는 기업',
#  '글로벌 위 를 노리 고 는 기업 니 만큼 갈라치기 없이 보상 을 해 면 겠 습니다',
#  '그냥저냥 무난 회사 라고 한다 그냥저냥 다니 기 은',
#  '즉 군 간 차별 고 연봉 도 동등 장점 자 단점 는 곳',
#  '반도체 현장 에서 배울 는 전문 인 생산 프로세스 를 배울 는 곳 다',
#  '만족 스럽 게 다니 고는 으나 회사 에 대한 믿음 을 조금 씩 잃 어 는',
#  '대 기업 답 게 처우 지만 아서 체력 으로 힘 듦',
#  '나쁘 도 지만 만족 스럽 아 애매 다',
#  '복지 정말 대박 고 삼성 라는 네임 드 에 아 심 돈 도 많이 줌',
#  '힘들 지만 에 대한 보상 은 는 곳 왜 대한민국 든 기업 인지 다',
#  '전기 관리자 에게 어 초고압 에서 말단 저압 까지 관리 할 는 은 기회',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 10019/10019 [00:00<00:00, 323495.65it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('개발자', 0.15694533369213087), ('개발', 0.05249237447360403), ('대우', 0.05051100126060147), ('로서', 0.028902379970994256), ('으며', 0.02307524032574678), ('성장', 0.021650176390661652), ('에게', 0.020798572637299565), ('으면서', 0.01692220926165278), ('커리어', 0.015467873873793857), ('환경', 0.014732240604022501)]
# 1 번째 토픽 : [('연봉', 0.06353160837171838), ('복지', 0.0559725440785026), ('급여', 0.04340199771450764), ('적당', 0.04262372282708098), ('만족', 0.031903752016811324), ('최고', 0.027181969370382742), ('수준', 0.025225482561911382), ('월급', 0.022354705820361042), ('안정', 0.018436514966314398), ('입니다', 0.017107333038450828)]
# 2 번째 토픽 : [('대한민국', 0.10774371204678788), ('한국', 0.08639257448734279), ('서울', 0.04944578191453031), ('최고', 0.033025738782208165), ('대표', 0.031190708258937484), ('기업', 0.030502392635404503), ('에서', 0.02507413627444272), ('글로벌', 0.01511281624462399), ('으로', 0.01437401987336292), ('공기업', 0.013237936673939152)]
# ...

# %%
model.save('/content/drive/MyDrive/after_incumbent_model')
