# %% [markdown]
# <a href="https://colab.research.google.com/github/NaDaGyeong/AIHumanity/blob/main/%EC%BD%94%EB%A1%9C%EB%82%98_%EC%A0%84%ED%9B%84_%EC%A0%84%EC%A7%81%EC%9E%90_%EC%9E%A5%EB%8B%A8%EC%A0%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 설치

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING: bertopic 0.13.0 does not provide the extra 'visualization'
# ...

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 4.71 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-02-11 12:42:27--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::3403:4be7, 2406:da00:ff00::22e9:9f55, ...
# ...

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 2.31 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-02-11 12:43:41--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# ...

# %% [markdown]
# # 데이터 전처리

# %%
from bertopic import BERTopic
import pandas as pd

# %%
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from bertopic import BERTopic

# %%
docs = pd.read_csv('/content/drive/MyDrive/jobplanet_df_stopword_preprocessed_0203.csv')

# %%
docs.head()
# Out:
#      회사        날짜         직무 재직여부  별점  \
# 0  삼성전자  2023. 01      생산/제조  전직원   4
# 1  삼성전자  2023. 01  생산관리/품질관리  전직원   2
# 2  삼성전자  2023. 01         개발  현직원   4
# 3  삼성전자  2023. 01         개발  현직원   3
# 4  삼성전자  2023. 01      기획/경영  현직원   1
#
#                                         요약                                 장점  \
# 0                       힘들 그만큼 급여 높 만족 던 곳                 힘든 만큼 급여 높 밥 정말 맛있
# 1             대 기업 라 부서 별 극 극 편하 구린 개고생 한다                   PS 맨 자부심 대 기업 복지
# 2  국내 최대 회사 복지 급여 괜찮 편 회사 버 돈 비해선 상당히 인색 함         회사 니 그냥 묻 티 난다 월급 루팡 무원 가능
# 3                       임원직 마음 대로 회사 처럼 회사      복지 워 라벨 편 이나 사업 부 사업장 냐 차이 심하
# 4        실제 주요 의사 결정권자 한국식 꼰대 판치 니 전혀 비전 곳  테이크아웃 셔틀 인지 보너스 많이 나올 기준 적당 인성 동료
#
#                                                   단점  \
# 0                                   인해 많이 피곤 연고지 랑 멀
# 1  F 직군 그냥 헬 대체 초 가능 인력 업무 방식 주먹구구 이슈 터지 부서 책임 회피...
# 2                              연봉 피에스 영향 많이 열심히 인정 못
# ...

# %%
docs['날짜']=pd.to_datetime(docs['날짜'])

# %%
# 코로나 전 데이터
before = docs.query("날짜<'2020-01-01'")

# %%
# 코로나 후 데이터
after = docs.query("날짜>='2020-01-01'")

# %%
#before.to_csv('/content/drive/MyDrive/before_0203.csv')

# %%
#after.to_csv('/content/drive/MyDrive/after_0203.csv')

# %%
before.fillna('', inplace=True)

# %%
after.fillna('', inplace=True)

# %%
# 코로나 전 + 전직원
before_former = before.query("재직여부=='전직원'")
before_former.head()
# Out:
#         회사         날짜         직무 재직여부  별점  \
# 3612  삼성전자 2019-12-01  생산관리/품질관리  전직원   1
# 3615  삼성전자 2019-12-01      기획/경영  전직원   3
# 3616  삼성전자 2019-12-01         개발  전직원   4
# 3619  삼성전자 2019-12-01       연구개발  전직원   4
# 3620  삼성전자 2019-12-01      엔지니어링  전직원   4
#
#                                        요약  \
# 3612               빛 개살구 내부 상황 매우 형광 뺀다거나
# 3615      국내 알아주 기업 안정 된 직장 이나 기업 문화 후진 임
# 3616  세계 최대 회사 역량 치열 내부 경쟁 따른 높 성과 경험 해 볼
# 3619         글로벌 개발자 협업 며 개인 커리어 성장 시켜 나갈
# 3620                  역시 대 기업 다운 연봉 복지 경험
#
#                                                      장점  \
# 3612                                       자체 장점 그만큼 단점
# 3615                      안정 된 직장 직장 브랜드 평판 적정 급여 수준 복지
# 3616  기업 인지 설명 해도 알아주 삼성전자 사업 부 대한 자부심 중소기업 연봉 수준 해당...
# 3619             개발 제품 소프트웨어 수많 사용 보람 느낄 세끼 무료 제공 식사 맛있
# 3620                                    교대 근무 긴 보다 돈 복지
#
#                                                      단점  \
# ...

# %%
# 코로나 후 + 전직원
after_former = after.query("재직여부=='전직원'")
after_former.head()
# Out:
#       회사         날짜         직무 재직여부  별점                            요약  \
# 0   삼성전자 2023-01-01      생산/제조  전직원   4            힘들 그만큼 급여 높 만족 던 곳
# 1   삼성전자 2023-01-01  생산관리/품질관리  전직원   2  대 기업 라 부서 별 극 극 편하 구린 개고생 한다
# 5   삼성전자 2023-01-01      기획/경영  전직원   5     커리어 쌓 기 급여 수중 높 대체 만족 스러움
# 9   삼성전자 2023-01-01         개발  전직원   4                   개발자 기 회사 만큼
# 10  삼성전자 2023-01-01      생산/제조  전직원   5             든 기업 답 게 급여 제공 기업
#
#                                               장점  \
# 0                             힘든 만큼 급여 높 밥 정말 맛있
# 1                               PS 맨 자부심 대 기업 복지
# 5                      연차 눈치 쓸 급여 수준 괜찮 조직 문화 나쁘
# 9   사내 분위기 업무 량 다름 밥 굳이 먹 으러 나갈 필요 프리랜서 라도 대우 나쁘
# 10                           자유 연차 높 급여 복지 미래 기업
#
#                                                    단점  \
# 0                                    인해 많이 피곤 연고지 랑 멀
# 1   F 직군 그냥 헬 대체 초 가능 인력 업무 방식 주먹구구 이슈 터지 부서 책임 회피...
# 5                          딱히 찾 순 워라 밸 깨지 부마부 구조 외 딱히
# ...

# %%
#before_former.to_csv('/content/drive/MyDrive/before_former_0203.csv')
#after_former.to_csv('/content/drive/MyDrive/after_former_0203.csv')

# %% [markdown]
# # 코로나 전 전직 단점 토픽 모델링

# %%
before_former['단점']
# Out:
# 3612     여성 승진 어려움 상사 평가 할 상사 친한 고과 줌 열심히 해서 성과 이룬다 해도 ...
# 3615              상하 관계 강한 직장 문화 사업 부 간 부서 간 연봉 근무 불 평등 존재
# 3616     조직 별 전혀 공정 성과 구조 임 게 게 반영 부서 타이밍 는지 재수 으면 상위 고...
# 3619                             도덕 못한 발생 지탄 는대서 자괴감 느껴집니다
# 3620                                교대 근무 라서 생활 패턴 일정 맞 힘들
#                                ...
# 37074                  기술력 측면 미래 는다 오토 합병 시 회사 도움 자리 차지 한다
# 37077       기업 보수 임 시스템 체계 중구난방 제대로 이해 기 힘 듦 연구소 보안 대 기업 맞
# 37078    팀 배치 업무 량 상 영업 이나 구매 팀 업무 과다 규모 비해 직원 스태프 부서 기...
# 37079    팀 다르 겠 분위기 부서 빡센 부서 나눠 짐 대 기업 종사 온 입사 퇴사 듦 진짜 ...
# 37083          회식 잦 듯 분위기 술 좋아하 권유 함 오래 다닐 거 라면 술 먹 어야 할 듯
# Name: 단점, Length: 8549, dtype: object

# %%
df = before_former['단점'].to_list()

# %%
df
# Out:
# ['여성 승진 어려움 상사 평가 할 상사 친한 고과 줌 열심히 해서 성과 이룬다 해도 묵묵히 승진 빛 못함 퇴사 후 동종 업계 연간 재취업 불가 강제 서명 해야 함 경력 단절 생김',
#  '상하 관계 강한 직장 문화 사업 부 간 부서 간 연봉 근무 불 평등 존재',
#  '조직 별 전혀 공정 성과 구조 임 게 게 반영 부서 타이밍 는지 재수 으면 상위 고과 발탁 가능 비 메인 부서 시스템 인프라 환경 진급 려고 노력 조직자 위한 과도 문서 작업',
#  '도덕 못한 발생 지탄 는대서 자괴감 느껴집니다',
#  '교대 근무 라서 생활 패턴 일정 맞 힘들',
#  '단점 수직 구조 윗사람 무조건 해야 구조 라서 았',
#  '근무 끝나 피곤 니 함',
#  '딱히 단점 뽑 뽑 자면 교통 너무나 유동 니 출퇴근 엄청나 게 막힌다 퇴근 거리 짧 몰리 퇴근 대 어쩔 없이 배 퇴근 늘어난다',
#  '비합리 팀장 주먹구구식 인사 평가 보수 조직 문화 실력 어도 운 게 취업 해서 일류 기업 다닌다는 자만심 거만 함 가득 동료 점점 짐',
#  '여러 업무 진행 해야 한다 학벌 대한 차별 스며들',
#  '부마부 소속 지역 별 지역 장 별로 천차만별 개인 적응 맞춰 스타일 라면 단점 회사',
#  '야근 요 상사 갈굼 인해 힘들',
#  '성과급 제도 기 경쟁 된다 어쩔 치열 경쟁 구조',
#  '기업 단점 라고 학력 인맥 실력 으론 느 어렵 대한민국 살아가 빠질 조건 기 노력 겠',
#  '문화 바꾸 려는 아이디어 실천 함 바뀌 겠 죠',
#  '근무 라고 는데 당시 야근 았 빠르 게 진행',
#  '협업 부서원 들이 간혹 이건 케 바케 듯',
#  '예전 어서 임원 똥 된장 라고 대답 해야 분위기 많이 바뀌 GWP 문화 정착 면서 점점 분위기 느슨 해짐',
#  '업무 나눠져 기 로드 걸릴 시 전체 스톱 된다',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 8549/8549 [00:00<00:00, 269880.29it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('문화', 0.020893509341260254), ('서울', 0.01578077394148512), ('부서', 0.014553331126620179), ('회사', 0.01361963586414689), ('기업', 0.01249979813982514), ('업무', 0.011892968224040835), ('근무', 0.010942340051437653), ('연봉', 0.01074953186306057), ('노조', 0.009971857249248782), ('직원', 0.009919744315857295)]
# 1 번째 토픽 : [('인턴', 0.01905230683402957), ('필요', 0.018221790056786136), ('근무', 0.017819829259241013), ('워라', 0.017744906373772965), ('느낌', 0.01730026432010303), ('딱히', 0.016400029875813564), ('부서', 0.01587393325181739), ('업무', 0.01541626110976779), ('체계', 0.01418875277557722), ('굉장히', 0.013669502477899768)]
# 2 번째 토픽 : [('군대', 0.1231534770218865), ('문화', 0.10958708497515636), ('군대식', 0.10452691209286596), ('아직', 0.03641036684045774), ('꼰대', 0.02365571570749941), ('조직', 0.023202832274893604), ('으며', 0.021986792478239425), ('라면', 0.019463793136722713), ('존재', 0.01809414842716441), ('합니다', 0.01745291141345789)]
# ...

# %%
#model.save('/content/drive/MyDrive/before_former_cons_model_0203')

# %% [markdown]
# # 코로나 후 전직 단점 토픽 모델링

# %%
import pandas as pd
after_former = pd.read_csv('/content/drive/MyDrive/after_former_0203.csv')

# %%
after_former.head()
# Out:
#    Unnamed: 0    회사          날짜         직무 재직여부  별점  \
# 0           0  삼성전자  2023-01-01      생산/제조  전직원   4
# 1           1  삼성전자  2023-01-01  생산관리/품질관리  전직원   2
# 2           5  삼성전자  2023-01-01      기획/경영  전직원   5
# 3           9  삼성전자  2023-01-01         개발  전직원   4
# 4          10  삼성전자  2023-01-01      생산/제조  전직원   5
#
#                              요약                                            장점  \
# 0            힘들 그만큼 급여 높 만족 던 곳                            힘든 만큼 급여 높 밥 정말 맛있
# 1  대 기업 라 부서 별 극 극 편하 구린 개고생 한다                              PS 맨 자부심 대 기업 복지
# 2     커리어 쌓 기 급여 수중 높 대체 만족 스러움                     연차 눈치 쓸 급여 수준 괜찮 조직 문화 나쁘
# 3                   개발자 기 회사 만큼  사내 분위기 업무 량 다름 밥 굳이 먹 으러 나갈 필요 프리랜서 라도 대우 나쁘
# 4             든 기업 답 게 급여 제공 기업                           자유 연차 높 급여 복지 미래 기업
#
#                                                   단점  \
# 0                                   인해 많이 피곤 연고지 랑 멀
# 1  F 직군 그냥 헬 대체 초 가능 인력 업무 방식 주먹구구 이슈 터지 부서 책임 회피...
# ...

# %%
after_former['단점']
# Out:
# 0                                         인해 많이 피곤 연고지 랑 멀
# 1        F 직군 그냥 헬 대체 초 가능 인력 업무 방식 주먹구구 이슈 터지 부서 책임 회피...
# 2                               딱히 찾 순 워라 밸 깨지 부마부 구조 외 딱히
# 3                                  게 단점 이유 밥 먹 으니 줄 서 게 귀찮
# 4                                     지방 라 출퇴근 걸림돌 이외 엔 단점
#                                ...
# 12690                       사업장 구성원 또는 팀장 님 성향 밑 업무 방식 개인차
# 12691    당연 팀원 만나 됨 팀 물어볼 거 부탁 할 게 어서 연락 답장 옴 애타 상황 자주 ...
# 12692               군대 조직 상하 관계 꼰대 상사 출근 빠름 시 출근 해도 늦 다고 함
# 12693                         S 다르 세상 공짜 으며 분위기 으나 군대 문화 편
# 12694                  승진 이나 일부 인사 시스템 그리 만족 스럽 았 감수 해야 부분
# Name: 단점, Length: 12695, dtype: object

# %%
after_former.fillna('', inplace=True)

# %%
df = after_former['단점'].to_list()

# %%
df
# Out:
# ['인해 많이 피곤 연고지 랑 멀',
#  'F 직군 그냥 헬 대체 초 가능 인력 업무 방식 주먹구구 이슈 터지 부서 책임 회피 온 힘 쏟 느낌 보람 다고 된다 그냥 회용 부속품 뇌 빼 면서 서 줄 대 기업 연봉 분 추천',
#  '딱히 찾 순 워라 밸 깨지 부마부 구조 외 딱히',
#  '게 단점 이유 밥 먹 으니 줄 서 게 귀찮',
#  '지방 라 출퇴근 걸림돌 이외 엔 단점',
#  '서류 작업 복잡 작업 대한 준비 과정 까다롭 환경 안전 경영 방침 위험 작업 중지',
#  '쏟아지 페이퍼 워크 업무 대해 책임 높 기대 기 힘든 워 라벨 결산 일정 대한 압박 동료 능력 자라 경쟁 어려움',
#  '실적 중요 했 던 압박 시달렸 던 거 아요 능률 만 따지 듯',
#  '임원 신인 곳 쓸데없 많이 불 필요 는데 그게 업무 할 임',
#  '상대 박탈감 타 사업 부 비해 인센티브 인한 불 평등 이나 당사자 만 억울 해 할 뿐 회사 전체 이게 공평 다고 한다',
#  '대체로 높 업무 강도 회사 미래 대해 게 됨 아래 목소리 위 올라가 한계',
#  '멀리 아서 다루 분야 좁',
#  '교대 생산 업무 특성 상 업무 피로감 어쩔',
#  '시스템 따른 인력 배치 보다 개개인 적성 맞 인력 배치 필요 해 보입니다 신입 적성 맞 업무 배치 이루어지',
#  '근무 강도 높 으며 경쟁 치열 해 직급 올라갈수록 업무 관계 대한 스트레스 높',
#  '승진 힘들 공채 우선주 잡무',
#  '돈 많이 이유 당연히 힘들 솔직히 힘든 회사 겠 냐 만',
#  '보수 학벌 문화 아직 남 듯 개인플레이',
#  '꼰대 향연 부서 서 로서',
#  '많이 시킴 균형 게 시켜야 는데 몰 아서 다가 한가 다가 반복',
#  '부바 부스 따른 업무 량 다름 끊임없 경쟁 따른 피로감',
#  '짧 직업 수명 불안 미래 정규직 아닌 공 장로 돈 만 다니 게 됨',
#  '선배 시험 봐야 한다 진급 할',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 12695/12695 [00:00<00:00, 160603.63it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 10):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05), ('', 1e-05)]
# 1 번째 토픽 : [('업무', 0.076039629532224), ('문화', 0.04542801013390936), ('회사', 0.04342178247107003), ('많이', 0.0431708827388102), ('기업', 0.041929454470452716), ('단점', 0.04085881271070639), ('부서', 0.03478243238577634), ('연봉', 0.034531370572000515), ('근무', 0.034329983453987536), ('직원', 0.03277826760727994)]
# 2 번째 토픽 : False
# 3 번째 토픽 : False
# 4 번째 토픽 : False
# 5 번째 토픽 : False
# 6 번째 토픽 : False
# 7 번째 토픽 : False
# 8 번째 토픽 : False
# 9 번째 토픽 : False

# %%
#model.save('/content/drive/MyDrive/after_former_cons_model_0203')

# %% [markdown]
# # 코로나 전 전직 장점 토픽 모델링

# %%
import pandas as pd
before_former = pd.read_csv('/content/drive/MyDrive/before_former_0203.csv')

# %%
before_former.fillna('', inplace=True)

# %%
before_former['장점']
# Out:
# 0                                            자체 장점 그만큼 단점
# 1                           안정 된 직장 직장 브랜드 평판 적정 급여 수준 복지
# 2       기업 인지 설명 해도 알아주 삼성전자 사업 부 대한 자부심 중소기업 연봉 수준 해당...
# 3                  개발 제품 소프트웨어 수많 사용 보람 느낄 세끼 무료 제공 식사 맛있
# 4                                         교대 근무 긴 보다 돈 복지
#                               ...
# 8544    부서 별 다르 겠 대체로 위크 앤 라이프 밸런스 측면 압도 조건 할 쉬 날 연봉 편...
# 8545                            연봉 매우 높 복지 쉬 날 회사 배 된다 노조
# 8546           네임 밸류 초봉 본사 역삼동 근무 가능 노조 힘 세 서 사원 대리 자잘 휴가
# 8547        대 기업 니 연봉 사원 대리 쉬 날 본사 보다 연구소 여서 자유 복장 자유 분위기
# 8548                         글로벌 기업 자부심 느낄 구내식당 종류 별 나와 맛
# Name: 장점, Length: 8549, dtype: object

# %%
df = before_former['장점'].to_list()

# %%
df
# Out:
# ['자체 장점 그만큼 단점',
#  '안정 된 직장 직장 브랜드 평판 적정 급여 수준 복지',
#  '기업 인지 설명 해도 알아주 삼성전자 사업 부 대한 자부심 중소기업 연봉 수준 해당 성과 급부 바보 자율 출퇴근 분 단위 이용 가능 여름 반바지 허용 가능 근무 복장',
#  '개발 제품 소프트웨어 수많 사용 보람 느낄 세끼 무료 제공 식사 맛있',
#  '교대 근무 긴 보다 돈 복지',
#  '장점 복리 후생 분기 당 만 씩 복지 포인트 며 피복비 나온다',
#  '급여 밥 맛있 통근 버스 다양 해서',
#  '장점 당연히 복지 구내식당 식당 먹 못해도 지원 해 준다 아르바이트 생 인센티브 준다 퇴근 준 해 며 외 퇴근 당연히 야근 수당 따로 챙겨준다',
#  '모든 알아주 회사 다닌다는 자부심 생김 높 연봉 다양 복지 흙 수저 삶 윤택 해질',
#  '급여 동종 직종 대비 여러 업무 경험 할',
#  '자율 출퇴근 수평 문화 근무 지점 조 석식 무료 제공 수원 디지털 시티 근무 게 복지 가장',
#  '야근 연차 자유 롭 게 사용 할 기업 입니다 추천',
#  '유복 입 어도 상관없 편하 게 다닐 듯이 밥 맛있',
#  '든지 시 대한민국 기업 곳 기 든 든 만 경력 메리트 기 았',
#  '자율 출퇴근 복지 대한민국 모범 생 가장 많이 다니 회사',
#  '나름 대로 합리 노조 직원 복지 괜찮 편 라고 합니다',
#  '대 기업 계약직 연봉 높 괜찮 정규직 보다 낮 워 라벨 회사',
#  '임원 목표 열심히 매진 정말 어렵 라인 운대 모든 게 삼위일체 돼야 함',
#  '급여 높 으며 연차 사용 제약 인턴 십 과정 임 중소기업 정규직 보다 급여 높',
#  '복리 후생 편 시설 서울 경기 지역 든 다니 출퇴근 버스 정말 큰 장점 입니다 회사 이름 프라이드 게 파란 피 됩니다',
#  '연차 눈치 쓸 연봉 워 라벨 즐길 사내 문화 괜찮',
#  '연차 쓸 분위기 아서 맘 편하 게 할',
#  '가족 분위기 이름 으며 대해 시 밥 나옵니다',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 8549/8549 [00:00<00:00, 372614.90it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('강도', 0.18196797553462574), ('업무', 0.14991429563745895), ('분야', 0.09776669262161516), ('장점', 0.09171522957146667), ('요령', 0.08476101578461734), ('기업', 0.0836026233083337), ('세세', 0.08241297407940623), ('묵묵히', 0.08241297407940623), ('봉급', 0.08241297407940623), ('함부로', 0.08241297407940623)]
# 1 번째 토픽 : [('항공', 0.26747772245105994), ('항공사', 0.12324378406306657), ('여행', 0.11393533039830231), ('혜택', 0.08961493659219723), ('항공업', 0.06729999315940051), ('해외', 0.06541440157760336), ('취항', 0.062250121775833396), ('비행기', 0.061345127867537944), ('나라', 0.06056701386505425), ('승무원', 0.060526526476645796)]
# 2 번째 토픽 : [('한국', 0.11168871895556126), ('대한민국', 0.09437761831610346), ('서울', 0.08862193444526602), ('삼성전자', 0.07041420358343091), ('기업', 0.06354758580275668), ('회사', 0.05036358138144607), ('최고', 0.04788405142047184), ('자부심', 0.04357275760093272), ('장점', 0.04209153047965862), ('근무', 0.03848024669969685)]
# ...

# %% [markdown]
# # 코로나 후 전직 장점 토픽 모델링

# %%
after_former = pd.read_csv('/content/drive/MyDrive/after_former_0203.csv')

# %%
after_former.fillna('', inplace=True)

# %%
after_former['장점']
# Out:
# 0                                       힘든 만큼 급여 높 밥 정말 맛있
# 1                                         PS 맨 자부심 대 기업 복지
# 2                                연차 눈치 쓸 급여 수준 괜찮 조직 문화 나쁘
# 3             사내 분위기 업무 량 다름 밥 굳이 먹 으러 나갈 필요 프리랜서 라도 대우 나쁘
# 4                                      자유 연차 높 급여 복지 미래 기업
#                                ...
# 12690               업무 프로세스 잡혀 이슈 발생 시 유관 부서 문 시 도움 많이 됩니다
# 12691    체계 시스템 갖춰 어서 신입 기 회사 복지 매우 뛰어나 유연 근무 출퇴근 설정 가능...
# 12692                                     복지 본인 노력 성장 할 한계
# 12693                           높 연봉 인지 직원 네트워크 가질 플랫 폼 획득
# 12694                             전체 복지 나쁘 케 바케 기 팀원 도움 많이
# Name: 장점, Length: 12695, dtype: object

# %%
df = after_former['장점'].to_list()

# %%
df
# Out:
# ['힘든 만큼 급여 높 밥 정말 맛있',
#  'PS 맨 자부심 대 기업 복지',
#  '연차 눈치 쓸 급여 수준 괜찮 조직 문화 나쁘',
#  '사내 분위기 업무 량 다름 밥 굳이 먹 으러 나갈 필요 프리랜서 라도 대우 나쁘',
#  '자유 연차 높 급여 복지 미래 기업',
#  '의료비 지원 리조트 수당 풍부 복리 후생 혜택',
#  '능력 출중 동료 체계 갖춰 짐 선진 시스템 식당 메뉴 아서 먹 거 골라 먹',
#  '아무래도 네임 밸류 큰 파랑 목걸이 느낌',
#  '글로벌 대 기업 만큼 전 세계 산업 한국 본사 시작 한다는 자부심',
#  '생활 가전 라 해서 특별 장점 진 기본 삼성전자 복지 거 막 잘난 척 봤 생활 가전 니까',
#  '대부분 직원 업무 대 전문 성 배울 판단 해야 할 대해 명확 결론 날 높 총 급여 업무 분담 확실 편 라 만 된다',
#  '한국 최고 기업 답 게 법 배울 최고 산업 후속 경력 영향 끼침',
#  '높 연봉 업무 대한 아낌없 지원 다양 교육 시스템',
#  '대 기업 국내 최고 기술력 배울 커리어 장점 됩니다',
#  '높 보수 풍족 복지 남자 라도 사용 가능 육아 휴직 기업 최고 장점 입니다',
#  '연차 윗사람 눈치 쓸 점심 맛있',
#  '큰 회사 기 복지 회사 프라이드 상당히 높 덕분 어깨 으쓱 다닐 만 했',
#  '할 연봉 복지 시스템 커리어 쌓 기 편',
#  '타 기업 대비 뚜렷 장점 밥맛 괜찮 아요 시 세끼',
#  '밥 며 복지 회사 그만두 회사 밥 생각나 게 회사',
#  '한국 대표 글로벌 기업 자부심 업무 스케일 경력 개발',
#  '삼성전자 란 이름값 높 연봉 워라 밸 모든 게 기업 모범 표준',
#  '밥 맛있 개발 할 선배 연차 자유',
#  '아침 점심 저녁 챙겨 돈 많이 복지 괜찮 편',
#  '강도 비해 급여 복지 상여금 나옵니다',
#  '발전 할 성장 가능 급여 복지 타 회사 놈',
#  '건물 시설 았 으며 제공 여러 복지 았 연봉 높 편 성과 금 으며 수당',
# ...

# %%
preprocessed_documents = []

for line in tqdm(df):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 12695/12695 [00:00<00:00, 405010.19it/s]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(df)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('분위기', 0.021690580242076964), ('눈치', 0.018460225005782586), ('연차', 0.018165778798540172), ('아요', 0.016942718762194362), ('가능', 0.01339805588027297), ('챙겨', 0.013102159167434358), ('편하', 0.01290222459192026), ('휴가', 0.01281535448080917), ('해서', 0.012711930237717117), ('없이', 0.012642615425305785)]
# 1 번째 토픽 : [('맛있', 0.0629024965022605), ('식당', 0.050730794227204924), ('식사', 0.042987300541498595), ('점심', 0.02946134053072373), ('구내식당', 0.026206693311869554), ('사내', 0.022584068672530183), ('메뉴', 0.021505505878481854), ('제공', 0.017461529437710246), ('복지', 0.01714817115970166), ('시설', 0.016635153562257254)]
# 2 번째 토픽 : [('서울', 0.028797883269692733), ('국내', 0.020103934495912107), ('기업', 0.01613956740999144), ('문화', 0.015907796473985485), ('연봉', 0.014103120106625263), ('사내', 0.014050048235574646), ('최고', 0.013497955894882304), ('회사', 0.013233100340855312), ('가능', 0.012906222201695223), ('자유', 0.012136051344047011)]
# ...
